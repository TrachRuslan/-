# %% [markdown]
# <a href="https://colab.research.google.com/github/TrachRuslan/-/blob/main/untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
content_counts = df['Content Rating'].value_counts()

plt.figure(figsize=(8,8))

plt.pie(content_counts,
        labels=content_counts.index,
        autopct='%1.1f%%')

plt.title('Розподіл додатків за віковими категоріями')

plt.show()
