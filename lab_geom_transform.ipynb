# %% [markdown]
# <a href="https://colab.research.google.com/github/TrachRuslan/-/blob/main/lab_geom_transform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
flip = cv2.flip(img, 1)

plt.imshow(flip)
plt.title("Віддзеркалення")
plt.show()
